# %% [markdown]
# # Contents and why we need this lab
#
# This lab is about implementing neural networks yourself before we start using other frameworks which hide some of the computation from you. It builds on the first lab where you derived the equations for neural network forward and backward propagation and gradient descent parameter updates.
#
# All the frameworks for deep learning you will meet from now on uses automatic differentiation (autodiff) so you don't have to code the backward step yourself. In this version of this lab you will develop your own autodif implementation. We also have a [version](https://github.com/DeepLearningDTU/02456-deep-learning-with-PyTorch/blob/master/2_Feedforward_NumPy/2.1-FNN-NumPy.ipynb) of this lab where you have to code the backward pass explicitly in Numpy.

# %% [markdown]
# # External sources of information
#
# 1. Jupyter notebook. You can find more information about Jupyter notebooks [here](https://jupyter.org/). It will come as part of the [Anaconda](https://www.anaconda.com/) Python installation.
# 2. [NumPy](https://numpy.org/). Part of Anaconda distribution. If you already know how to program most things about Python and NumPy can be found through Google search.
# 3. [Nanograd](https://github.com/rasmusbergpalm/nanograd) is a minimalistic version of autodiff developed by Rasmus Berg Palm that we use for our framework.

# %% [markdown]
# # This notebook will follow the next steps:
#
# 1. Nanograd automatic differentiation framework
# 2. Finite difference method
# 3. Data generation
# 4. Defining and initializing the network
# 5. Forward pass
# 6. Training loop
# 7. Testing your model
# 8. Further extensions

# %% [markdown]
# # Nanograd automatic differention framework

# %% [markdown]
# The [Nanograd](https://github.com/rasmusbergpalm/nanograd) framework defines a class Var which both holds a value and gradient value that we can use to store the intermediate values when we apply the chain rule of differentiation.

# %%
# Copy and pasted from https://github.com/rasmusbergpalm/nanograd/blob/main/nanograd.py

from math import exp, log

class Var:
    """
    A variable which holds a float and enables gradient computations.
    """

    def __init__(self, val: float, grad_fn=lambda: []):
        assert type(val) == float
        self.v = val
        self.grad_fn = grad_fn
        self.grad = 0.0

    def backprop(self, bp):
        self.grad += bp
        for input, v in self.grad_fn():
            input.backprop(v * bp)

    def backward(self):
        self.backprop(1.0)

    def __add__(self: 'Var', other: 'Var') -> 'Var':
        return Var(self.v + other.v, lambda: [(self, 1.0), (other, 1.0)])

    def __mul__(self: 'Var', other: 'Var') -> 'Var':
        return Var(self.v * other.v, lambda: [(self, other.v), (other, self.v)])

    def __pow__(self, power):
        assert type(power) in {float, int}, "power must be float or int"
        return Var(self.v ** power, lambda: [(self, power * self.v ** (power - 1))])

    def __neg__(self: 'Var') -> 'Var':
        return Var(-1.0) * self

    def __sub__(self: 'Var', other: 'Var') -> 'Var':
        return self + (-other)

    def __truediv__(self: 'Var', other: 'Var') -> 'Var':
        return self * other ** -1

    def __repr__(self):
        return "Var(v=%.4f, grad=%.4f)" % (self.v, self.grad)

    def relu(self):
        return Var(self.v if self.v > 0.0 else 0.0, lambda: [(self, 1.0 if self.v > 0.0 else 0.0)])

# %% [markdown]
# ### Quick testing
#
# Testing how addition between a Var and a non-Var works

# %%
a = Var(3.0)
print(a)
b = a * 2
print(b)
# Out:
# Var(v=3.0000, grad=0.0000)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\daflo\Documents\DTU\Semester_7\02456_Deep_Learning\Code\Week_2\2.1-EXE-FNN-AutoDif-Nanograd.ipynb Cell 8 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/daflo/Documents/DTU/Semester_7/02456_Deep_Learning/Code/Week_2/2.1-EXE-FNN-AutoDif-Nanograd.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> a = Var(3.0)
#       <a href='vscode-notebook-cell:/c%3A/Users/daflo/Documents/DTU/Semester_7/02456_Deep_Learning/Code/Week_2/2.1-EXE-FNN-AutoDif-Nanograd.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> print(a)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/daflo/Documents/DTU/Semester_7/02456_Deep_Learning/Code/Week_2/2.1-EXE-FNN-AutoDif-Nanograd.ipynb#X10sZmlsZQ%3D%3D?line=2'>3</a> b = a * 2
# ...

# %% [markdown]
# A few examples illustrate how we can use this:

# %%
a = Var(3.0)
b = Var(5.0)
f = a * b

f.backward()

for v in [a, b, f]:
    print(v)
# Out:
# Var(v=3.0000, grad=5.0000)
# Var(v=5.0000, grad=3.0000)
# Var(v=15.0000, grad=1.0000)

# %%
a = Var(3.0)
b = Var(5.0)
c = a * b
d = Var(9.0)
e = a * d
f = c + e

f.backward()

for v in [a, b, c, d, e, f]:
    print(v)
# Out:
# Var(v=3.0000, grad=14.0000)
# Var(v=5.0000, grad=3.0000)
# Var(v=15.0000, grad=1.0000)
# Var(v=9.0000, grad=3.0000)
# Var(v=27.0000, grad=1.0000)
# Var(v=42.0000, grad=1.0000)

# %% [markdown]
# ## Exercise a) What is being calculated?
#
# Explain briefly the output of the code? What is the expression we differentiate and with respect to what variables?

# %% [markdown]
# The expression being differentiated is:
# $$
# f = a \cdot (d + b)
# $$
# It is being differentiated with respect to $a, b, d$.

# %% [markdown]
# ## Exercise b) How does the backward function work?
#
# You need to understand how the backward function calculates the gradients. We can use the two examples above to help with that.
#
# Go through the following four steps and answer the questions on the way:
#
# 1. We represent the two expressions as graphs as shown below. Fill in the missing expressions for the different derivatives.
#
# 2. In the remainder consider the first expression. Make a schematic of the data structure which is generated when we define the expression for f.
#
# 3. Then execute the backward function by hand to convince yourself that it indeed calculates the gradients with respect to the variables.
#
# 4. Write down the sequence of calls to backprop.

# %%
# import logging
import graphviz

# logging.basicConfig(format='[%(levelname)s@%(name)s] %(message)s', level=logging.DEBUG)

#graphviz.__version__, graphviz.version()

# %%
e1 = graphviz.Digraph('first expression', filename='fsm.gv')

e1.attr(rankdir='LR', size='8,5')

e1.attr('node', shape='circle')
e1.edge('a', 'f', label='df/da=b')
e1.edge('b', 'f', label='df/db=a')

e1

# %%
e2 = graphviz.Digraph('second expression', filename='fsm.gv')

e2.attr(rankdir='LR', size='8,5')

e2.attr('node', shape='circle')
e2.edge('a', 'c', label='dc/da=b')
e2.edge('b', 'c', label='dc/db=a')
e2.edge('a', 'e', label='de/da=d')
e2.edge('d', 'e', label='de/dd=a')
e2.edge('c', 'f', label='df/dc=1')
e2.edge('e', 'f', label='df/de=1')

e2

# %% [markdown]
# ## Exercise c) What happens if we run backward again?
#
# Try to execute the code below. Explain what happens.

# %%
f.backward()

for v in [a, b, c, d, e, f]:
    print(v)
# Out:
# Var(v=3.0000, grad=28.0000)
# Var(v=5.0000, grad=6.0000)
# Var(v=15.0000, grad=2.0000)
# Var(v=9.0000, grad=6.0000)
# Var(v=27.0000, grad=2.0000)
# Var(v=42.0000, grad=2.0000)

# %% [markdown]
# It does the same operation again, but mathematically it makes no sense.
# I also drew it out:

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

plt.figure()
img = mpimg.imread("images/program_execution.jpg")
imgplot = plt.imshow(img)
plt.axis("off")
plt.show()

# %% [markdown]
# ## Exercise d) Zero gradient
#
# We can zero the gradient by backpropagating a -1.0 as is shown in the example below. (If you have run backward multiple time then you also have to run the cell below an equal amount of times.) Explain what is going on.

# %%
a = Var(2.0)

for v in [a, b, c, d, e, f]:
    print(v)

print()
f.backprop(-1.0)

for v in [a, b, c, d, e, f]:
    print(v)
# Out:
# Var(v=2.0000, grad=0.0000)
# Var(v=5.0000, grad=6.0000)
# Var(v=15.0000, grad=2.0000)
# Var(v=9.0000, grad=6.0000)
# Var(v=27.0000, grad=2.0000)
# Var(v=42.0000, grad=2.0000)
#
# Var(v=2.0000, grad=0.0000)
# Var(v=5.0000, grad=3.0000)
# Var(v=15.0000, grad=1.0000)
# Var(v=9.0000, grad=3.0000)
# Var(v=27.0000, grad=1.0000)
# Var(v=42.0000, grad=1.0000)

# %% [markdown]
# This backprop function is a completely reversible function. That is why `f.backrop(-1)` resets the computational graph to one step before. Additionally, doing `f.backprop(-1)` and equal amount of times as `f.backward()` would completely reset the computational graph.

# %% [markdown]
# ## Exercise e) Test correctness of derivatives with the finite difference method
#
# Write a small function that uses [the finite difference method](https://en.wikipedia.org/wiki/Finite_difference_method) to numerically test that backpropation implementation is working. In short we will use
# $$
# \frac{\partial f(a)}{\partial a} \approx \frac{f(a+da)-f(a)}{da}
# $$
# for $da \ll 1$.
#
# As an example, we could approximate the derivative of the function $f(a)=a^2$ in e.g. the value $a=4$ using the finite difference method. This amounts to inserting the relevant values and approximating the gradient $f'(4)$ with the fraction above.

# %%
# f function - try to change the code to test other types of functions as well (such as different polynomials etc.)
def f_function(x):
  a = Var(x)
  f = a * a
  f.backward()
  return a, f

for v in f_function(4.0):
  print(v)

# Insert your finite difference code here
def finite_difference(x, da=1e-10):
    """
    This function compute the finite difference between
    
    Input:
    da:          The finite difference                           (float)
    
    Output:
    finite_difference: numerical approximation to the derivative (float) 
    """
    
    fa_da = (x + da)**2           
    fa = x**2               

    finite_difference = (fa_da - fa) / da
    
    return finite_difference

print(finite_difference(4.0))
# Out:
# Var(v=4.0000, grad=8.0000)
# Var(v=16.0000, grad=1.0000)
# 8.000000661922968

# %% [markdown]
# # Create an artificial dataset to play with
#
# We create a non-linear 1d regression task. The generator supports various noise levels and it creates train, validation and test sets. You can modify it yourself if you want more or less challenging tasks.

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(42)

# %%
def data_generator(noise=0.1, n_samples=300, D1=True):
    # Create covariates and response variable
    if D1:
        X = np.linspace(-3, 3, num=n_samples).reshape(-1,1) # 1-D
        np.random.shuffle(X)
        y = np.random.normal((0.5*np.sin(X[:,0]*3) + X[:,0]), noise) # 1-D with trend
    else:
        X = np.random.multivariate_normal(np.zeros(3), noise*np.eye(3), size = n_samples) # 3-D
        np.random.shuffle(X)    
        y = np.sin(X[:,0]) - 5*(X[:,1]**2) + 0.5*X[:,2] # 3-D

    # Stack them together vertically to split data set
    data_set = np.vstack((X.T,y)).T
    
    train, validation, test = np.split(data_set, [int(0.35*n_samples), int(0.7*n_samples)], axis=0)
    
    # Standardization of the data, remember we do the standardization with the training set mean and standard deviation
    train_mu = np.mean(train, axis=0)
    train_sigma = np.std(train, axis=0)
    
    train = (train-train_mu)/train_sigma
    validation = (validation-train_mu)/train_sigma
    test = (test-train_mu)/train_sigma
    
    x_train, x_validation, x_test = train[:,:-1], validation[:,:-1], test[:,:-1]
    y_train, y_validation, y_test = train[:,-1], validation[:,-1], test[:,-1]
    
    # ***Own Notes***
    # print("x_train\n", x_train)
    # print(f"x_train type: {type(x_train)}")
    print(f"x_train shape: {x_train.shape}")
    return x_train, y_train,  x_validation, y_validation, x_test, y_test

# %%
D1 = True
x_train, y_train,  x_validation, y_validation, x_test, y_test = data_generator(noise=0.5, D1=D1)
# Out:
# x_train shape: (105, 1)

# %%
from cProfile import label


if D1:
    plt.scatter(x_train[:,0], y_train, label="Train");
    plt.scatter(x_validation[:,0], y_validation, label="Val");
    plt.scatter(x_test[:,0], y_test, label="Test");
    plt.legend()
else:
    plt.scatter(x_train[:,1], y_train);
    plt.scatter(x_validation[:,1], y_validation);
    plt.scatter(x_test[:,1], y_test);
plt.show()

# %%
# convert from nparray to Var
def nparray_to_Var(x):
  if x.ndim==1:
    y = [[Var(float(x[i]))] for i in range(x.shape[0])] # always work with list of list
  else:
    y = [[Var(float(x[i,j])) for j in range(x.shape[1])] for i in range(x.shape[0])]
  return y
   
x_train = nparray_to_Var(x_train)
y_train = nparray_to_Var(y_train)
x_validation = nparray_to_Var(x_validation)
y_validation = nparray_to_Var(y_validation)
x_test = nparray_to_Var(x_test)
y_test = nparray_to_Var(y_test)

# %% [markdown]
# ## Exercise f) Add more activation functions
#
# To have a full definition of the neural network, we must define an activation function for every layer. Several activation functions have been proposed and have different characteristics. In the Var class we have already defined the rectified linear init (relu).
#
# Implement the following activation functions in the Var class:
#
# * Identity: $$\mathrm{identity}(x) = x$$
# * Hyperbolic tangent: $$\tanh(x)$$
# * Sigmoid (or logistic function): $$\mathrm{sigmoid}(x) = \frac{1}{1.0 + \exp(-x ) }$$  Hint: $\mathrm{sigmoid}'(x)= \mathrm{sigmoid}(x)(1-\mathrm{sigmoid}(x))$.
#
# Hint: You can seek inspiration in the relu method in the Var class.

# %%
from math import exp, log, tanh

class Var:
    """
    A variable which holds a float and enables gradient computations.
    """

    def __init__(self, val: float, grad_fn=lambda: []):
        assert type(val) == float
        self.v = val
        self.grad_fn = grad_fn
        self.grad = 0.0

    def backprop(self, bp):
        self.grad += bp
        for input, v in self.grad_fn():
            input.backprop(v * bp)

    def backward(self):
        self.backprop(1.0)

    def __add__(self: 'Var', other: 'Var') -> 'Var':
        return Var(self.v + other.v, lambda: [(self, 1.0), (other, 1.0)])

    def __mul__(self: 'Var', other: 'Var') -> 'Var':
        return Var(self.v * other.v, lambda: [(self, other.v), (other, self.v)])

    def __pow__(self, power):
        assert type(power) in {float, int}, "power must be float or int"
        return Var(self.v ** power, lambda: [(self, power * self.v ** (power - 1))])

    def __neg__(self: 'Var') -> 'Var':
        return Var(-1.0) * self

    def __sub__(self: 'Var', other: 'Var') -> 'Var':
        return self + (-other)

    def __truediv__(self: 'Var', other: 'Var') -> 'Var':
        return self * other ** -1

    def __repr__(self):
        return "Var(v=%.4f, grad=%.4f)" % (self.v, self.grad)

    def relu(self):
        return Var(self.v if self.v > 0.0 else 0.0, lambda: [(self, 1.0 if self.v > 0.0 else 0.0)])
    
    def identity(self):
        return self
    
    def hyperbolic_tangent(self):
        # Updates the value     and             the gradient
        return Var(tanh(self.v), lambda: [(self, 1 - tanh(self.v)**2)])
    
    def sigmoid(self):
        # Utilizes a lambda-function so it looks nicer
        sigmoid_shortcut = lambda x: 1/(1 + exp(-x))
        
        # Updates the value     and                         the gradient
        return Var(sigmoid_shortcut(self.v), lambda: [(self, (sigmoid_shortcut(self.v))*(1 - sigmoid_shortcut(self.v)) )])

# %% [markdown]
# # Defining and initializing the network
#
# The steps to create a feed forward neural network are the following:
#
# 1. **Number of hidden layer and hidden units**. We have to define the number of hidden units in each layer. The number of features in X and the output dimensionality (the size of Y) are given but the numbers in between are set by the researcher. Remember that for each unit in each layer beside in the input has a bias term.
# 2. **Activation functions** for each hidden layer. Each hidden layer in your list must have an activation function (it can also be the linear activation which is equivalent to identity function). The power of neural networks comes from non-linear activation functions that learn representations (features) from the data allowing us to learn from it.
# 3. **Parameter initialization**. We will initialize the weights to have random values. This is done in practice by drawing pseudo random numbers from a Gaussian or uniform distribution. It turns out that for deeper models we have to be careful about how we scale the random numbers. This will be the topic of the exercise below. For now we will just use unit variance Gaussians.
#
# In order to make life easier for ourselves we define a DenseLayer class that takes care of initialization and the forward pass. We can also extend it later with print and advanced initialization capabilities. For the latter we have introduced an Initializer class.
#
# Note that we use Sequence in the code below. A Sequence is an ordered list. This means the order we insert and access items are the same.

# %%
class Initializer:

  def init_weights(self, n_in, n_out):
    raise NotImplementedError

  def init_bias(self, n_out):
    raise NotImplementedError

# %%
import random

class NormalInitializer(Initializer):
# ***OWN NOTES***
# A class that sets all the biases and weights of the network to
# a random gaussian value (as the name would indicate).
# NOTE:
# I don't know why this is a class and not just a class function..!?

  def __init__(self, mean=0, std=0.1):
    self.mean = mean
    self.std = std

  def init_weights(self, n_in, n_out):
    # ***OWN NOTES***
    # Weights are initialized Gaussian (i.e. normal distribution).
    return [[Var(random.gauss(self.mean, self.std)) for _ in range(n_out)] for _ in range(n_in)]

  def init_bias(self, n_out):
    # ***OWN NOTES***
    # Setting an initial bias with value zero for every single output Node.
    return [Var(0.0) for _ in range(n_out)]


class ConstantInitializer(Initializer):
# ***OWN NOTES***
# A class that sets all the biases and weights of the network to
# a constant value (as the name would indicate).
# NOTE:
# I don't know why this is a class and not just a class function..!?

  def __init__(self, weight=1.0, bias=0.0):
    self.weight = weight
    self.bias = bias

  def init_weights(self, n_in, n_out):
    # Set all the weights to the same value.
    return [[Var(self.weight) for _ in range(n_out)] for _ in range(n_in)]

  def init_bias(self, n_out):
    # Set all the biases to the same value.
    return [Var(self.bias) for _ in range(n_out)]

# %%
from typing import Sequence

class DenseLayer:
    def __init__(self, n_in: int, n_out: int, activation_fun, initializer = NormalInitializer()):
        # ***OWN NOTES***
        # Simplie initialization based on the initializers as defined above.
        self.weights = initializer.init_weights(n_in, n_out)
        self.bias = initializer.init_bias(n_out)
        self.activation_fun = activation_fun
    
    def __repr__(self):    
        return f"Weights: {repr(self.weights)}\nBiases: {repr(self.bias)}"

    def parameters(self) -> Sequence[Var]:
        # ***OWN NOTES***
        # This was that super-weird list-concatanation bull-shit,
        # where all of our weights are just concatenated into a single string.
        # And then at the very end the bias is added.
        params = []
        for r in self.weights:
            params += r

        return params + self.bias

    def forward(self, single_input: Sequence[Var]) -> Sequence[Var]:
        # TODO!
        # write comments!
        
        # self.weights is a matrix with dimension n_in x n_out. We check that the dimensionality of the input 
        # to the current layer matches the number of nodes in the current layer
        assert len(self.weights) == len(single_input), "weights and single_input must match in first dimension"
        weights = self.weights
        out = []
        
        # For some given data point single_input, we now want to calculate the resulting value in each node in the current layer
        # We therefore loop over the (number of) nodes in the current layer:
        for i in range(len(weights[0])): 
            # Initialize the node value depending on its corresponding parameters.
            node = self.bias[i] # <- Insert code
            # We now finish the linear transformation corresponding to the parameters of the currently considered node.
            for j in range(len(single_input)):
                node += weights[j][i]*single_input[j]  # <- Insert code
            node = self.activation_fun(node)
            out.append(node)

        return out

# %% [markdown]
# ## Exercise g) Complete the forward pass
#
# In the code below we initialize a 1-5-1 network and pass the training set through it. *The forward method in DenseLayer is **not** complete*. It just outputs zeros right now. The method forward should perform an [affine transformation](https://en.wikipedia.org/wiki/Affine_transformation) on the input followed by an application of the activation function.

# %%
NN = [
    DenseLayer(1, 5, lambda x: x.relu()),
    DenseLayer(5, 1, lambda x: x.identity())
]

def forward_single(x, network):
  # ***OWN NOTES***
  # Why was this defined inside the forward function???
  # then it would be redefined if we ever called forward again... just seems useless.
  for layer in network:
      x = layer.forward(x)
  return x
  
def forward(input_x, network):
  # ***OWN NOTES***
  # forward takes an input, and a network represented as a list.
  # Then that network and all the elements of the input are
  # parsed to the forward_single(), iteratively.
  
  # In forward_single() we call each layers forward() parsing every
  # single element of the input.

  output = [ forward_single(element, network) for element in input_x]
  return output

print(forward(x_train, NN))

# %% [markdown]
# ## Exercise h) Print all network parameters
#
# Make a function that prints all the parameters of the network (weights and biases) with information about in which layer they appear. In the object oriented spirit you should introduce a method in the DenseLayer class to print the parameters of a layer. Hint: You can take inspiration from the corresponding method in Var.

# %%
# Insert code here and in the DenseLayer class
# This seems so triviel that I am unsure whether I even did anything or anything that was right
for layer_index, layer in enumerate(NN):
    print(f"Layer {layer_index}:")
    print(f"{layer}\n")
# Out:
# Layer 0:
# Weights: [[Var(v=0.0319, grad=0.0000), Var(v=0.2342, grad=0.0000), Var(v=0.0158, grad=0.0000), Var(v=0.0754, grad=0.0000), Var(v=-0.0463, grad=0.0000)]]
# Biases: [Var(v=0.0000, grad=0.0000), Var(v=0.0000, grad=0.0000), Var(v=0.0000, grad=0.0000), Var(v=0.0000, grad=0.0000), Var(v=0.0000, grad=0.0000)]
#
# Layer 1:
# Weights: [[Var(v=0.0474, grad=0.0000)], [Var(v=0.0296, grad=0.0000)], [Var(v=-0.0845, grad=0.0000)], [Var(v=-0.0214, grad=0.0000)], [Var(v=0.0624, grad=0.0000)]]
# Biases: [Var(v=0.0000, grad=0.0000)]

# %% [markdown]
# ## Visualization
#
# Now that we have defined our activation functions we can visualize them to see what they look like:

# %%
x = np.linspace(-6, 6, 100)

# convert from Var to ndarray  
def Var_to_nparray(x):
  y = np.zeros((len(x), len(x[0]) ))
  
  for i in range(len(x)):
    for j in range(len(x[0])):
      y[i, j] = x[i][j].v
  return y

# define 1-1 network with weight = 1 and relu activation 
#
# ***OWN NOTES***
# We do this by using the ConstantInitializer, which initializes all the weights to a
# set value.
NN = [ DenseLayer(1, 1, lambda x: x.relu(), initializer = ConstantInitializer(1.0)) ] 
y = Var_to_nparray(forward(nparray_to_Var(x), NN))

#y = Var_to_nparray(relu(nparray_to_Var(x)))
plt.plot(x,y)

# %%
# Testing all activation layers

x = np.linspace(-6, 6, 100)
units = {
    "identity": lambda x: x.identity(),
    "sigmoid": lambda x: x.sigmoid(),  # <- uncomment before sharing
    "relu": lambda x: x.relu(),
    "tanh": lambda x: x.hyperbolic_tangent() # <- uncomment before sharing
}

plt.figure(figsize=(5, 5))
[plt.plot(x, Var_to_nparray(forward(nparray_to_Var(x), [DenseLayer(1, 1, unit, initializer = ConstantInitializer(1.0))]) ), label=unit_name, lw=2) for unit_name, unit in units.items()] # unit(nparray_to_Var(x))), label=unit_name, lw=2) for unit_name, unit in units.items()]
plt.legend(loc=2, fontsize=16)
plt.title('Our activation functions', fontsize=20)
plt.ylim([-2, 5])
plt.xlim([-6, 6])
plt.show()

# %% [markdown]
# # Advanced initialization schemes
#
# If we are not careful with initialization, the signals we propagate forward ($a^{(l)}$, $l=1,\ldots,L$) and backward ($\delta^l$, $l=L,L-1,\ldots,1$) can blow up or shrink to zero. A statistical analysis of the variance of the signals for different activation functions can be found in these two papers: [Glorot initialization](http://proceedings.mlr.press/v9/glorot10a/glorot10a.pdf) and [He initialization](https://arxiv.org/pdf/1502.01852v1.pdf).
#
# The result of the analyses are proposals for how to make the initialization such that the variance of the signals (forward and backward) are kept approxmimatly constant when propagating from layer to layer. The exact expressions depend upon the non-linear activation function used. In Glorot initialization, the aim is to keep both the forward and backward variances constant whereas He only aims at keeping the variance in the forward pass constant.
#
# We define $n_{in}$ and $n_{out}$ as the number of input units and output units of a particular layer.
#
# The Glorot initialization has the form:
#
# $$w_{ij} \sim N \bigg( 0, \, \frac{2 \alpha }{n_{in} + n_{out}} \bigg) \ . $$
#
# where $N(\mu,\sigma^2)$ is a Gaussian distribution with mean $\mu$ and variance $\sigma^2$ and $\alpha$ is a parameter that depends upon the activation function used. For $\tanh$, $\alpha=1$ and for Rectified Linear Unit (ReLU) activations, $\alpha=2$. (It is also possible to use a uniform distribution for initialization, see [this blog post](https://mmuratarat.github.io/2019-02-25/xavier-glorot-he-weight-init).)
#
# The He initialization is very similar
#
# $$w_{ij} \sim N \bigg( 0, \, \frac{\alpha}{n_{in}} \bigg) \ . $$

# %% [markdown]
# ## Exercise i) Glorot and He initialization
#
# Using the Initializer class, implement functions that implement Glorot and He
#
# Explain briefly how you would test numerically that these initializations have the sought after property. Hint: See plots in Glorot paper.
#
# Comment: If you want to be more advanced then try to make a universal initializer taking both the activation function and type (Glorot or He) as argument.

# %% [markdown]
# ### Solution i)
# This class does not work with the how the dense layer was implemented. But I felt that this was a good implementation and I simply couldn't be bothered to rewrite a whole bunch of code.

# %%
# *** OWN NOTES ***
# The gaussian function we are using takes the mean and the standard deviation.
# However we are given the variance and as such we should take the squareroot of it, to obtain the std.

class Initializer:
  
  def __init__(self, n_in : int, n_out : int):
    if type(n_in) is not int or type(n_out) is not int:
      raise TypeError("Your dimensionality must be of type int!")
    else:
      self.n_in = n_in
      self.n_out = n_out
  
  # Constant functions
  def init_weights_constant(self, weight : float = 1.0, ):
    # Set all the weights to the same value.
    return [[Var(weight) for _ in range(self.n_out)] for _ in range(self.n_in)]
  
  def init_weights_constant(self, bias : float = 0.0):
    # Set all the biases to the same value.
    return [Var(bias) for _ in range(self.n_out)]
  
  
  # normal functions
  def init_weights_normal(self, mean : float = 0.0, std : float = 0.1):
    # Weights are initialized Gaussian (i.e. normal distribution).
    return [[Var(random.gauss(mean, std)) for _ in range(self.n_out)] for _ in range(self.n_in)]

  def init_bias_normal(self):
    # Setting an initial bias with value zero for every single output Node.
    return [Var(0.0) for _ in range(self.n_out)]  
    
  
  # glorot functions
  def init_weights_glorot(self, activation_fun : str):
    test_fun = activation_fun.lower()
    if test_fun == "identity" or test_fun == "sigmoid" or test_fun == "tanh" or test_fun == "hyperbolic tangent" or test_fun == "relu":
      self.activation_fun = test_fun
      
      if test_fun == "tanh" or test_fun == "hyperbolic tangent":
        self.alpha = 1
        
      elif test_fun == "relu":
        self.alpha = 2
      
      else:
        # Mean and standard deviation zero is probably not the right way to handle it
        # ... ¯\_(ツ)_/¯
        self.alpha = 0
    
      # Weights are initialized by the Glorot function (i.e. normal distribution with mean zero and weird std).
      return [[Var(random.gauss(0, np.sqrt((2*self.alpha)/(self.n_in + self.n_out))) ) for _ in range(self.n_out)] for _ in range(self.n_in)]
        
    else:
      raise ValueError("The activation function you tried to use isn't defined!")
    
  def init_bias_glorot(self):
    # Setting an initial bias with value zero for every single output Node.
    return [Var(0.0) for _ in range(self.n_out)]  
  
  
  # He functions
  def init_weights_he(self, activation_fun : str):
    test_fun = activation_fun.lower()
    if test_fun == "identity" or test_fun == "sigmoid" or test_fun == "tanh" or test_fun == "hyperbolic tangent" or test_fun == "relu":
      self.activation_fun = test_fun
      
      if test_fun == "tanh" or test_fun == "hyperbolic tangent":
        self.alpha = 1
        
      elif test_fun == "relu":
        self.alpha = 2
      
      else:
        # Mean and standard deviation zero is probably not the right way to handle it
        # ... ¯\_(ツ)_/¯
        self.alpha = 0
    
      # Weights are initialized by the He function (i.e. normal distribution with mean zero and weird std).
      return [[Var(random.gauss(0, np.sqrt(self.alpha/self.n_in )) ) for _ in range(self.n_out)] for _ in range(self.n_in)]
        
    else:
      raise ValueError("The activation function you tried to use isn't defined!")

# %% [markdown]
# By the Glorot and He initilization we aim to keep the variance of the signals close to constant, when propagating back and forth through layers. A way to test whether the above implementation achieves this, could be print, logging or plotting the variance of the signals, from layer to layer.
#
# For further analysis this could be tested against a simple gaussian initiliaztion to see whether there is significant difference.

# %% [markdown]
# ## Exercise j) Forward pass unit test
#
# Write a bit of code to make a unit test that the forward pass works. This can be done by defining a simple network with for example all weights equal to one (using the ConstantInitializer method) and identity activation functions.
#
# Hints: Use the [assert](https://www.w3schools.com/python/ref_keyword_assert.asp), the nparray_to_Var and the Var_to_nparray commands.

# %% [markdown]
# ### Solution j)
# Could have used the Glorot/ He-initialization, but simply couldn't be bothered to change a whole bunch of code again.

# %%
x = np.linspace(-6, 6, 100)


# define 1-1 network with weight = 1 and relu activation 
#
# ***OWN NOTES***
# We do this by using the ConstantInitializer, which initializes all the weights to a
# set value.
NN = [ DenseLayer(1, 1, lambda x: x.identity(), initializer = ConstantInitializer(1.0)) ] 
y = Var_to_nparray(forward(nparray_to_Var(x), NN))

#y = Var_to_nparray(relu(nparray_to_Var(x)))
plt.plot(x,y)

# %%
x = np.linspace(-6, 6, 100)


# define 1-1 network with weight = 1 and relu activation 
#
# ***OWN NOTES***
# We do this by using the ConstantInitializer, which initializes all the weights to a
# set value.
NN = [ DenseLayer(1, 2, lambda x: x.identity(), initializer = ConstantInitializer(4.0)), 
      DenseLayer(2, 1, lambda x: x.identity(), initializer = ConstantInitializer(1.5)) ]
y = Var_to_nparray(forward(nparray_to_Var(x), NN))

#y = Var_to_nparray(relu(nparray_to_Var(x)))
plt.plot(x,y)

# %% [markdown]
# # Loss functions
#
# We are only missing a loss function to we need to define a loss function and its derivative with respect to the output of the neural network $y$

# %%
def squared_loss(t, y):
  
  # add check that sizes agree

  def squared_loss_single(t, y):
    Loss = Var(0.0)
    for i in range(len(t)): # sum over outputs
      Loss += (t[i]-y[i]) ** 2
    return Loss

  Loss = Var(0.0)
  for n in range(len(t)): # sum over training data
    Loss += squared_loss_single(t[n],y[n])
  return Loss

# %% [markdown]
# ## Exercise j) Implement cross entropy loss
#
# Insert code below to implement cross-entropy loss for general dimensionality of $t$. Use a logits formulation:
# $$
# \rm{Loss} = - \sum_i t_i \, log \, p_i
# $$
# with $p$ given by the the softmax function in terms of the logits $h$:
# $$
# p_i = \frac{\exp(h_i)}{\sum_{i'} \exp(h_{i'})} .
# $$
# Inserting $p$ in the expression for the loss gives
# $$
# \rm{Loss} = - \sum_i t_i h_i + \rm{LogSumExp}(h) \ ,
# $$
# where
# $$
# \rm{LogSumExp}(h) = \log \sum_i \exp h_i \ .
# $$
# This is true for $t$ being a one-hot vector.
#
# Call the function to convince yourself it works.
#
# In practice you want to implement a [numerically stable](https://leimao.github.io/blog/LogSumExp/) version of LogSumExp. But we will not bother about that here.
#
# Help: You can add these methods in the Var class:
#
#     def exp(self):
#         return Var(exp(self.v), lambda: [(self, exp(self.v))])
#
#     def log(self):
#         return Var(log(self.v), lambda: [(self, self.v ** -1)])

# %%
from math import exp, log, tanh

class Var:
    """
    A variable which holds a float and enables gradient computations.
    """

    def __init__(self, val: float, grad_fn=lambda: []):
        assert type(val) == float
        self.v = val
        self.grad_fn = grad_fn
        self.grad = 0.0

    def backprop(self, bp):
        self.grad += bp
        for input, v in self.grad_fn():
            input.backprop(v * bp)

    def backward(self):
        self.backprop(1.0)

    def __add__(self: 'Var', other: 'Var') -> 'Var':
        return Var(self.v + other.v, lambda: [(self, 1.0), (other, 1.0)])

    def __mul__(self: 'Var', other: 'Var') -> 'Var':
        return Var(self.v * other.v, lambda: [(self, other.v), (other, self.v)])

    def __pow__(self, power):
        assert type(power) in {float, int}, "power must be float or int"
        return Var(self.v ** power, lambda: [(self, power * self.v ** (power - 1))])

    def __neg__(self: 'Var') -> 'Var':
        return Var(-1.0) * self

    def __sub__(self: 'Var', other: 'Var') -> 'Var':
        return self + (-other)

    def __truediv__(self: 'Var', other: 'Var') -> 'Var':
        return self * other ** -1

    def __repr__(self):
        return "Var(v=%.4f, grad=%.4f)" % (self.v, self.grad)

    def relu(self):
        return Var(self.v if self.v > 0.0 else 0.0, lambda: [(self, 1.0 if self.v > 0.0 else 0.0)])
    
    def identity(self):
        return self
    
    def hyperbolic_tangent(self):
        # Updates the value     and             the gradient
        return Var(tanh(self.v), lambda: [(self, 1 - tanh(self.v)**2)])
    
    def sigmoid(self):
        # Utilizes a lambda-function so it looks nicer
        sigmoid_shortcut = lambda x: 1/(1 + exp(-x))
        
        # Updates the value     and                         the gradient
        return Var(sigmoid_shortcut(self.v), lambda: [(self, (sigmoid_shortcut(self.v))*(1 - sigmoid_shortcut(self.v)) )])
    
    
    # Added the functionality of both the exponential function and the natural logarithm to our Var class
    def exp(self):
        return Var(exp(self.v), lambda: [(self, exp(self.v))])
    
    def log(self):
        return Var(log(self.v), lambda: [(self, self.v ** -1)])

# %%
def cross_entropy_loss(t, h):
    if len(t) != len(h):
        raise Exception("Ya done goofed A-a-ron.")  
        
    Loss = Var(0.0)
    sumExp = Var(0.0)
    
    for i in range(len(t)):
        sumExp += h[i].exp()
        loss += t[i]*h[i]
        
    return -loss + sumExp.log()

# %% [markdown]
# # Backward pass
#
# Now the magic happens! We get the calculation of the gradients for free. Just do:

# %%
NN = [
    DenseLayer(1, 5, lambda x: x.relu()),
    DenseLayer(5, 1, lambda x: x.identity())
]

output = forward(x_train, NN)

Loss = squared_loss(y_train,output)
Loss.backward()

# %% [markdown]
# and the gradients will be calculated:

# %%
[print('Layer', i, '\n', NN[i]) for i in range(len(NN))]
# Out:
# Layer 0
#  Weights: [[Var(v=0.1958, grad=-6.5090), Var(v=-0.1403, grad=-21.7029), Var(v=-0.0331, grad=-5.8138), Var(v=-0.0211, grad=-2.9926), Var(v=-0.0216, grad=-9.9023)]]
# Biases: [Var(v=0.0000, grad=-5.5927), Var(v=0.0000, grad=19.7391), Var(v=0.0000, grad=5.2878), Var(v=0.0000, grad=2.7218), Var(v=0.0000, grad=9.0063)]
# Layer 1
#  Weights: [[Var(v=0.0650, grad=-19.6160)], [Var(v=0.2180, grad=13.9682)], [Var(v=0.0584, grad=3.2987)], [Var(v=0.0301, grad=2.0987)], [Var(v=0.0995, grad=2.1490)]]
# Biases: [Var(v=0.0000, grad=4.4479)]
# [None, None]

# %% [markdown]
# # Backward pass unit test
#
# Above we used finite differences to test that Nanograd is actually doing what it is supposed to do. We can in principle try the same for the neural network. But we will trust that the test above is enough.

# %% [markdown]
# # Training and validation
#
# We are ready to train some neural networks!
#
# We initialize again:

# %%
NN = [
    DenseLayer(1, 15, lambda x: x.relu()),
    DenseLayer(15, 50, lambda x: x.relu()),
    DenseLayer(50, 1, lambda x: x.identity())
]

output = forward(x_train, NN)

Loss = squared_loss(y_train,output)
Loss.backward()

# %% [markdown]
# and make an update:
#
# We introduce a help function parameters to have a handle in all parameters in the network.

# %%
print('Network before update:')
[print('Layer', i, '\n', NN[i]) for i in range(len(NN))] 

def parameters(network):
  params = []
  for layer in range(len(network)):
    params += network[layer].parameters()
  return params

def update_parameters(params, learning_rate=0.01):
  for p in params:
    p.v -= learning_rate*p.grad

def zero_gradients(params):
  for p in params:
    p.grad = 0.0

update_parameters(parameters(NN))

print('\nNetwork after update:')
[print('Layer', i, '\n', NN[i]) for i in range(len(NN))] 

zero_gradients(parameters(NN))

print('\nNetwork after zeroing gradients:')
[print('Layer', i, '\n', NN[i]) for i in range(len(NN))]

# %%
# Initialize an arbitrary neural network
NN = [
    DenseLayer(1, 8, lambda x: x.relu()),
    DenseLayer(8, 1, lambda x: x.identity())
]

# Recommended hyper-parameters for 3-D: 
#NN = [
#    DenseLayer(3, 16, lambda x: x.relu()),
#    DenseLayer(16, 1, lambda x: x.identity())
#]


### Notice that, when we switch from tanh to relu activation, we decrease the learning rate. This is due the stability of the gradients 
## of the activation functions.

# %%
# Initialize training hyperparameters
EPOCHS = 200
LEARN_R = 2e-3

# %%
train_loss = []
val_loss = []

for e in range(EPOCHS):
     
    # Forward pass and loss computation
    Loss = squared_loss(y_train, forward(x_train, NN))

    # Backward pass
    Loss.backward()
    
    # gradient descent update
    update_parameters(parameters(NN), LEARN_R)
    zero_gradients(parameters(NN))
    
    # Training loss
    train_loss.append(Loss.v)
    
    # Validation
    Loss_validation = squared_loss(y_validation, forward(x_validation, NN))
    val_loss.append(Loss_validation.v)
    
    if e%10==0:
        print("{:4d}".format(e),
              "({:5.2f}%)".format(e/EPOCHS*100), 
              "Train loss: {:4.3f} \t Validation loss: {:4.3f}".format(train_loss[-1], val_loss[-1]))
# Out:
#    0 ( 0.00%) Train loss: 98.391 	 Validation loss: 97.879
#   10 ( 5.00%) Train loss: 20.408 	 Validation loss: 17.523
#   20 (10.00%) Train loss: 14.423 	 Validation loss: 11.671
#   30 (15.00%) Train loss: 13.679 	 Validation loss: 10.719
#   40 (20.00%) Train loss: 13.258 	 Validation loss: 10.159
#   50 (25.00%) Train loss: 12.955 	 Validation loss: 9.734
#   60 (30.00%) Train loss: 12.693 	 Validation loss: 9.451
#   70 (35.00%) Train loss: 12.480 	 Validation loss: 9.270
#   80 (40.00%) Train loss: 12.339 	 Validation loss: 9.125
#   90 (45.00%) Train loss: 12.232 	 Validation loss: 9.052
#  100 (50.00%) Train loss: 12.146 	 Validation loss: 8.995
#  110 (55.00%) Train loss: 12.041 	 Validation loss: 8.964
#  120 (60.00%) Train loss: 11.982 	 Validation loss: 8.942
#  130 (65.00%) Train loss: 11.954 	 Validation loss: 8.932
#  140 (70.00%) Train loss: 11.935 	 Validation loss: 8.936
#  150 (75.00%) Train loss: 11.922 	 Validation loss: 8.943
# ...

# %%
plt.plot(range(len(train_loss)), train_loss, label="train loss");
plt.plot(range(len(val_loss)), val_loss, label="validation loss");
plt.legend()

# %% [markdown]
# # Testing
#
# We have kept the calculation of the test error separate in order to emphasize that you should not use the test set in optimization.

# %%
output_test = forward(x_test, NN)

# %%
y_test_np = Var_to_nparray(y_test)
plt.scatter(y_test_np, Var_to_nparray(output_test));
plt.plot([np.min(y_test_np), np.max(y_test_np)], [np.min(y_test_np), np.max(y_test_np)], color='k');
plt.xlabel("y");
plt.ylabel("$\hat{y}$");
plt.title("Model prediction vs real in the test set, the close to the line the better")
plt.grid(True);
plt.axis('equal');
plt.tight_layout();

Loss_test = squared_loss(y_test, forward(x_test, NN))

print("Test loss:  {:4.3f}".format(Loss_test.v))
# Out:
# Test loss:  9.802

# %%
x_test_np = Var_to_nparray(x_test)
x_train_np = Var_to_nparray(x_train)
y_train_np = Var_to_nparray(y_train)
if D1:
    plt.scatter(x_train_np, y_train_np, label="train data");
    plt.scatter(x_test_np, Var_to_nparray(output_test), label="test prediction");
    plt.scatter(x_test_np, y_test_np, label="test data");
    plt.legend();
    plt.xlabel("x");
    plt.ylabel("y");
else:
    plt.scatter(x_train_np[:,1], y_train, label="train data");
    plt.scatter(x_test_np[:,1], Var_to_nparray(output_test), label="test data prediction");
    plt.scatter(x_test_np[:,1], y_test_np, label="test data");
    plt.legend();
    plt.xlabel("x");
    plt.ylabel("y");

# %% [markdown]
# ## Exercise k) Show overfitting, underfitting and just right fitting
#
# Vary the architecture and other things to show clear signs of overfitting (=training loss significantly lower than test loss) and underfitting (=not fitting enoung to training data so that test performance is also hurt).
#
# See also if you can get a good compromise which leads to a low validation loss.
#
# For this problem do you see any big difference between validation and test loss? The answer here will probably be no. Discuss cases where it is important to keep the two separate.
#
# _Insert written answer here._

# %% [markdown]
# ### Creating a training function
# So that it will be easier to show the over-/ underfitting

# %%
def training_fun(network, epochs, lr):
    import time
    
    start_time = time.time()
    train_loss = []
    val_loss = []

    for epoch in range(epochs):
        
        # Forward pass and loss computation
        Loss = squared_loss(y_train, forward(x_train, network))

        # Backward pass
        Loss.backward()
        
        # gradient descent update
        update_parameters(parameters(network), lr)
        zero_gradients(parameters(network))
        
        # Training loss
        train_loss.append(Loss.v)
        
        # Validation
        Loss_validation = squared_loss(y_validation, forward(x_validation, network))
        val_loss.append(Loss_validation.v)
        
        if epoch%(epochs/10)==0:
            time_at_epoch = time.time()
            elapsed_time = time_at_epoch - start_time
            minutes =  int(elapsed_time // 60) if elapsed_time - 60 > 0 else 0
            seconds = int(elapsed_time - minutes*60)
            print(f"In {minutes}:{seconds} minutes",
                "{:4d}".format(epoch),
                "({:5.2f}%)".format(epoch/epochs*100), 
                "Train loss: {:4.3f} \t Validation loss: {:4.3f}".format(train_loss[-1], val_loss[-1]))

# %% [markdown]
# ### Overfitting
# Overfitting occours when our model learns the training data too well! So well in fact, that it does not generalize to the broader distribution that we in truth are trying to fit!
#
# Overfitting can happen due to multiple reasons: a training set that does not represent the entire distribution, a small training set, but most commonly it is overtraining a too complex model. This will create local minima in a very complex space, which might suit the training data very vell, but not necessarily the distribution as a whole.
#
# To achieve overfitting I therefore try a somewhat complex neural network (of four layers and two different activation functions) wich I ran for a lot of epochs and with a very small learning rate. Ideally this should get us stuck in one of these unwanted local minima.

# %% [markdown]
# #### Different tests
# I couldn't really achieve overfitting. I blame it on the linearity of the dataset.
# But I am gonna sound lazy, because I couldn't be bothered to make another dataset and and other tests.
#
# So instead I will just show some pictures of my different attempts.

# %%
# Initialize an arbitrary neural network
NN_overfit = [
    DenseLayer(1, 8, lambda x: x.relu()),
    DenseLayer(8, 16, lambda x: x.relu()),
    DenseLayer(16, 8, lambda x: x.relu()),
    DenseLayer(8, 1, lambda x: x.identity())
]

training_fun(NN_overfit, 1500, 7e-4)
# Out:
# In 0:2 minutes    0 ( 0.00%) Train loss: 105.194 	 Validation loss: 107.982
# In 4:11 minutes  150 (10.00%) Train loss: 15.040 	 Validation loss: 12.826
# In 8:32 minutes  300 (20.00%) Train loss: 12.274 	 Validation loss: 9.235
# In 12:55 minutes  450 (30.00%) Train loss: 11.906 	 Validation loss: 8.919
# In 16:55 minutes  600 (40.00%) Train loss: 11.858 	 Validation loss: 8.960
# In 20:54 minutes  750 (50.00%) Train loss: 11.826 	 Validation loss: 8.956
# In 25:22 minutes  900 (60.00%) Train loss: 11.777 	 Validation loss: 8.923
# In 37:34 minutes 1050 (70.00%) Train loss: 11.698 	 Validation loss: 8.856
# In 41:34 minutes 1200 (80.00%) Train loss: 11.574 	 Validation loss: 8.721
# In 45:40 minutes 1350 (90.00%) Train loss: 11.712 	 Validation loss: 8.699

# %% [markdown]
# First attempt at overfitting.

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

plt.figure()
img = mpimg.imread("images/test_1.png")
imgplot = plt.imshow(img)
plt.axis("off")
plt.show()

# %% [markdown]
# Second attempt at overfitting.
# (The network was simply too large, and I wasn't gonna burn further electricty doing these calculations in Python)

# %%
plt.figure()
img = mpimg.imread("images/test_2.png")
imgplot = plt.imshow(img)
plt.axis("off")
plt.show()

# %% [markdown]
# Third attempt at overfitting.

# %%
plt.figure()
img = mpimg.imread("images/test_3.png")
imgplot = plt.imshow(img)
plt.axis("off")
plt.show()

# %% [markdown]
# Fourth attempt at overfitting.

# %%
plt.figure()
img = mpimg.imread("images/test_4.png")
imgplot = plt.imshow(img)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Underfitting
# Underfitting occurs when we learn next to nothing about our data. This is when we never converge towards a minima and instead achieve a way to general fit of our data, that neither matches the test data nor the distribution as a whole.
#
# Underfitting usually happens when we train for too few epochs or/ and when we use a disproportionate learning rate - this can often be alleviated by the use of some learning-scheme. But that has, for obvious reasons, not been implemented in this notebook.
#
# Below is an example of a training gone horrible wrong, resulting in an exploding gradient... :/

# %%
# Initialize an arbitrary neural network
NN_underfit = [
    DenseLayer(1, 8, lambda x: x.relu()),
    DenseLayer(8, 1, lambda x: x.identity())
]

training_fun(NN_underfit, 30, 5e-1)
# Out:
# In 0:0 minutes    0 ( 0.00%) Train loss: 105.743 	 Validation loss: 92831.785
# In 0:0 minutes    3 (10.00%) Train loss: 2243957756468428085976303738337440117430360629443559424.000 	 Validation loss: 2968419486847762113621652544741594445843118277643105287614772220770718958601677861991589931395728574517618789449668049869834986665371860449989629888803677924589830144.000
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# c:\Users\daflo\Documents\DTU\Semester_7\02456_Deep_Learning\Code\Week_2\2.1-EXE-FNN-AutoDif-Nanograd.ipynb Cell 81 in <cell line: 7>()
#       <a href='vscode-notebook-cell:/c%3A/Users/daflo/Documents/DTU/Semester_7/02456_Deep_Learning/Code/Week_2/2.1-EXE-FNN-AutoDif-Nanograd.ipynb#Y143sZmlsZQ%3D%3D?line=0'>1</a> # Initialize an arbitrary neural network
# ...
